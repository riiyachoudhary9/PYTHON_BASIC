# %% [markdown]
# Find the topper?

# %%
marks=[45,67,89,34,90]

# %%
topper=0
for mark in marks:
    if mark > topper:
        topper=mark
        print("the toppers marks is :",topper)
# Out:
# the toppers marks is : 45
# the toppers marks is : 67
# the toppers marks is : 89
# the toppers marks is : 90

# %%
import numpy as np
arr=np.array([45,67,89,34,90])
print(arr.max())
print(arr.min())
print(arr.mean())
# Out:
# 90
# 34
# 65.0
